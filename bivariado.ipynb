# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
machines=pd.read_csv("./conjunto de datos/ALERTA.csv")
machines
# Out:
#         UDI Product ID Nombre_Producto   Type  Air temperature [K]  \
# 0         1     M14860   Producto 7004  Medio                298.1
# 1         2     L47181   Producto 1004   Bajo                298.2
# 2         3     L47182   Producto 1005   Bajo                298.1
# 3         4     L47183   Producto 1006   Bajo                298.2
# 4         5     L47184   Producto 1007   Bajo                298.2
# ...     ...        ...             ...    ...                  ...
# 9995   9996     M24855   Producto 9998  Medio                298.8
# 9996   9997     H39410   Producto 1002   Alto                298.9
# 9997   9998     M24857   Producto 9999  Medio                299.0
# 9998   9999     H39412   Producto 1003   Alto                299.0
# 9999  10000     M24859  Producto 10000  Medio                299.0
#
#       Process temperature [K]  Rotational speed [rpm]  Torque [Nm]  \
# 0                       308.6                    1551         42.8
# ...

# %%
machines_num = machines.select_dtypes(include='number')
matriz = machines_num.corr()
print(matriz)

plt.matshow(matriz, cmap='bwr', vmin=-1, vmax=1)
plt.xticks(range(len(matriz.columns)), machines_num.columns, rotation=90)
plt.yticks(range(len(matriz.columns)), machines_num.columns)

for i in range(len(matriz.columns)):
    for j in range(len(matriz.columns)):
        plt.text(i,j, round(matriz.iloc[i,j], 2),ha='center', va='center')

plt.colorbar()
plt.show()
# Out:
#                               UDI  Air temperature [K]  \
# UDI                      1.000000             0.117428
# Air temperature [K]      0.117428             1.000000
# Process temperature [K]  0.324428             0.876107
# Rotational speed [rpm]  -0.006615             0.022670
# Torque [Nm]              0.003207            -0.013778
# Tool wear [min]         -0.010702             0.013853
# Target                  -0.022892             0.082556
#
#                          Process temperature [K]  Rotational speed [rpm]  \
# UDI                                     0.324428               -0.006615
# Air temperature [K]                     0.876107                0.022670
# Process temperature [K]                 1.000000                0.019277
# Rotational speed [rpm]                  0.019277                1.000000
# Torque [Nm]                            -0.014061               -0.875027
# Tool wear [min]                         0.013488                0.000223
# ...

# %%
#Relacion entre altura y peso ...
plt.scatter(machines["Air temperature [K]"],machines["Rotational speed [rpm]"])
plt.xlabel("Air temperature [K]")
plt.ylabel("Rotational speed [rpm]")
# Out:
# Text(0, 0.5, 'Rotational speed [rpm]')

# %%
#Correlacion Pearson

coeficiente=machines["Air temperature [K]"].corr(machines['Rotational speed [rpm]'])
print(f"coeficiente Pearson: {coeficiente}")
# Out:
# coeficiente Pearson: 0.022670458795547133

# %% [markdown]
# # Relacion ingreso y horas trabajadas

# %%
plt.scatter(machines["Torque [Nm]"],machines["Process temperature [K]"])
plt.xlabel("Torque [Nm]")
plt.ylabel("Process temperature [K]")
# Out:
# Text(0, 0.5, 'Process temperature [K]')

# %%
plt.scatter(machines["Rotational speed [rpm]"],machines["Process temperature [K]"])
plt.xlabel("Rotational speed [rpm]")
plt.ylabel("Process temperature [K]")
# Out:
# Text(0, 0.5, 'Process temperature [K]')
