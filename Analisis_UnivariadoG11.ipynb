# %%
#importar la libreria
import pandas as pd
import seaborn as sns

# %%
#crear DataFrame apartir del archivo con la data 

df_Alerta = pd.read_csv('ALERTA.csv',sep=';')
df_Alerta
# Out:
#         UDI Producto ID Nombre_Producto   Tipo  Temperatura_Aire  \
# 0         1      M14860   Producto 7004  Medio             298.1
# 1         2      L47181   Producto 1004   Bajo             298.2
# 2         3      L47182   Producto 1005   Bajo             298.1
# 3         4      L47183   Producto 1006   Bajo             298.2
# 4         5      L47184   Producto 1007   Bajo             298.2
# ...     ...         ...             ...    ...               ...
# 9995   9996      M24855   Producto 9998  Medio             298.8
# 9996   9997      H39410   Producto 1002   Alto             298.9
# 9997   9998      M24857   Producto 9999  Medio             299.0
# 9998   9999      H39412   Producto 1003   Alto             299.0
# 9999  10000      M24859  Producto 10000  Medio             299.0
#
#       Temperatura_Proceso  Velocidad_Rotacion  Torque  Desgaste_Herramientas  \
# 0                   308.6                1551    42.8                      0
# ...

# %%
df_Alerta.info() #Muestra informacion del DF
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   UDI                    10000 non-null  int64
#  1   Producto ID            10000 non-null  object
#  2   Nombre_Producto        10000 non-null  object
#  3   Tipo                   10000 non-null  object
#  4   Temperatura_Aire       10000 non-null  float64
#  5   Temperatura_Proceso    10000 non-null  float64
#  6   Velocidad_Rotacion     10000 non-null  int64
#  7   Torque                 10000 non-null  float64
#  8   Desgaste_Herramientas  10000 non-null  int64
#  9   Objetivo               10000 non-null  int64
#  10  Tipo_de_falla          10000 non-null  object
# dtypes: float64(3), int64(4), object(4)
# memory usage: 859.5+ KB

# %%
# Traer nuestro tipo de datos 
df_Alerta.describe()
# Out:
#                UDI  Temperatura_Aire  Temperatura_Proceso  Velocidad_Rotacion  \
# count  10000.00000      10000.000000         10000.000000        10000.000000
# mean    5000.50000        300.004930           310.005560         1538.776100
# std     2886.89568          2.000259             1.483734          179.284096
# min        1.00000        295.300000           305.700000         1168.000000
# 25%     2500.75000        298.300000           308.800000         1423.000000
# 50%     5000.50000        300.100000           310.100000         1503.000000
# 75%     7500.25000        301.500000           311.100000         1612.000000
# max    10000.00000        304.500000           313.800000         2886.000000
#
#              Torque  Desgaste_Herramientas      Objetivo
# count  10000.000000           10000.000000  10000.000000
# mean      39.986910             107.951000      0.033900
# std        9.968934              63.654147      0.180981
# ...

# %%
df_Alerta.head(5) #Mostrar Primeras filas del df
df_Alerta.tail(5) #Mostrar ultimas filas del DF
# Out:
#         UDI Producto ID Nombre_Producto   Tipo  Temperatura_Aire  \
# 9995   9996      M24855   Producto 9998  Medio             298.8
# 9996   9997      H39410   Producto 1002   Alto             298.9
# 9997   9998      M24857   Producto 9999  Medio             299.0
# 9998   9999      H39412   Producto 1003   Alto             299.0
# 9999  10000      M24859  Producto 10000  Medio             299.0
#
#       Temperatura_Proceso  Velocidad_Rotacion  Torque  Desgaste_Herramientas  \
# 9995                308.4                1604    29.5                     14
# 9996                308.4                1632    31.8                     17
# 9997                308.6                1645    33.4                     22
# 9998                308.7                1408    48.5                     25
# 9999                308.7                1500    40.2                     30
#
#       Objetivo Tipo_de_falla
# 9995         0    No Failure
# 9996         0    No Failure
# ...

# %%
df_Alerta.shape #Muestra numero de filas y columnas
# Out:
# (10000, 11)

# %%
df_Alerta.Temperatura_Aire.dtype #Muestra tipo de dato de la columna
# Out:
# dtype('float64')

# %%
df_Alerta.columns #Mostrar nombres de columnas
# Out:
# Index(['UDI', 'Producto ID', 'Nombre_Producto', 'Tipo', 'Temperatura_Aire',
#        'Temperatura_Proceso', 'Velocidad_Rotacion', 'Torque',
#        'Desgaste_Herramientas', 'Objetivo', 'Tipo_de_falla'],
#       dtype='object')

# %%
df_Alerta.isnull().sum() #Cantidad de datos nulos por columna
# Out:
# UDI                      0
# Producto ID              0
# Nombre_Producto          0
# Tipo                     0
# Temperatura_Aire         0
# Temperatura_Proceso      0
# Velocidad_Rotacion       0
# Torque                   0
# Desgaste_Herramientas    0
# Objetivo                 0
# Tipo_de_falla            0
# dtype: int64

# %%
df_ventas.Unidades=df_ventas.Unidades.astype('int') #Convertir a otro tipo de dato
df_ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, C1008 to C9987
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Zona               1000 non-null   object
#  1   País               1000 non-null   object
#  2   Tipo_Producto      1000 non-null   object
#  3   Canal_Venta        1000 non-null   object
#  4   Prioridad          1000 non-null   object
#  5   Fecha_Pedido       999 non-null    datetime64[ns]
#  6   ID_Pedido          999 non-null    float64
#  7   Fecha_Envío        997 non-null    datetime64[ns]
#  8   Unidades           1000 non-null   int64
#  9   Precio_Unitario    1000 non-null   float64
#  10  Coste_Unitario     1000 non-null   object
#  11  ImporteVentaTotal  1000 non-null   float64
#  12  ImporteCosteTotal  1000 non-null   object
# dtypes: datetime64[ns](2), float64(3), int64(1), object(7)
# memory usage: 141.7+ KB

# %%
df_ventas[df_ventas['Coste_Unitario']=='50s,54']#Buscar por un dato
# Out:
#             Zona   País Tipo_Producto Canal_Venta Prioridad Fecha_Pedido  \
# ID_Cliente
# C1885       Asia  Nepal     Doméstico      Online   Crítica   2020-10-18
#
#               ID_Pedido Fecha_Envío  Unidades  Precio_Unitario Coste_Unitario  \
# ID_Cliente
# C1885       188509356.0  2020-10-31      2963           668.27         50s,54
#
#             ImporteVentaTotal ImporteCosteTotal
# ID_Cliente
# C1885              1980084.01        1489026.02

# %%
import numpy as np
#df_ventas[df_ventas['Coste_Unitario']==np.NaN]#Buscar por un dato

# %%
df_ventas[df_ventas["ImporteVentaTotal"]>4900000]
# Out:
#                               Zona                              País  \
# ID_Cliente
# C1314                       Europa                            Greece
# C1534                       África                           Namibia
# C1559                         Asia                      Turkmenistan
# C1647          Australia y Oceanía                           Vanuatu
# C1891                         Asia                        Kyrgyzstan
# C1940                       África                 Equatorial Guinea
# C2185                       Europa                        Luxembourg
# C2514                       África                          Cameroon
# C3205                       África                            Uganda
# C3324       Centroamérica y Caribe                             Haiti
# C3388                         Asia                             Nepal
# C3736       Centroamérica y Caribe                          Honduras
# ...

# %%
#total de venta por zona
#df_Alerta.groupby("Desgaste_Herramientas")["Tipo_de_falla"].sum()
# Out:
# Desgaste_Herramientas
# 0      No FailureNo FailureNo FailureNo FailureNo Fai...
# 2      No FailureNo FailureNo FailureNo FailureNo Fai...
# 3      No FailureNo FailureNo FailureNo FailureNo Fai...
# 4      No FailureNo FailureNo FailureNo FailureNo Fai...
# 5      No FailureNo FailureNo FailureNo FailureNo Fai...
#                              ...
# 242                                 No FailureNo Failure
# 244                       No FailureNo FailureNo Failure
# 246        Tool Wear FailureOverstrain FailureNo Failure
# 251                                   Overstrain Failure
# 253                                    Tool Wear Failure
# Name: Tipo_de_falla, Length: 246, dtype: object

# %%
#$funcion lambda
df_Alerta["NivelDesgaste"]=df_Alerta["Desgaste_Herramientas"].apply(lambda x: "Alta" if x>200 else "baja")
df_Alerta
# Out:
#         UDI Producto ID Nombre_Producto   Tipo  Temperatura_Aire  \
# 0         1      M14860   Producto 7004  Medio             298.1
# 1         2      L47181   Producto 1004   Bajo             298.2
# 2         3      L47182   Producto 1005   Bajo             298.1
# 3         4      L47183   Producto 1006   Bajo             298.2
# 4         5      L47184   Producto 1007   Bajo             298.2
# ...     ...         ...             ...    ...               ...
# 9995   9996      M24855   Producto 9998  Medio             298.8
# 9996   9997      H39410   Producto 1002   Alto             298.9
# 9997   9998      M24857   Producto 9999  Medio             299.0
# 9998   9999      H39412   Producto 1003   Alto             299.0
# 9999  10000      M24859  Producto 10000  Medio             299.0
#
#       Temperatura_Proceso  Velocidad_Rotacion  Torque  Desgaste_Herramientas  \
# 0                   308.6                1551    42.8                      0
# ...

# %%
df_Alerta.plot(kind="bar",color="orange", ylabel="Nombre_Producto" ,title="Productos a fallar")

# %%
df_zona=df_ventas.groupby("Zona")["Unidades"].sum()
df_zona
# Out:
# Zona
# Asia                       813961
# Australia y Oceanía        467682
# Centroamérica y Caribe     537316
# Europa                    1139265
# Norteamérica               114780
# África                    1951477
# Name: Unidades, dtype: int64

# %%
df_zona.plot(kind="pie",autopct="%1.1f%%", title="Distribucion de unidades",startangle=10, ylabel="")
# Out:
# <Axes: title={'center': 'Distribucion de unidades'}>

# %%
#grafico de dispersion
df_ventas.plot(kind="scatter", x="Prioridad", y="ImporteVentaTotal",color="r")
# Out:
# <Axes: xlabel='Prioridad', ylabel='ImporteVentaTotal'>

# %%
#Grafico histograma Distribucion de los datos de uan variable 

df_ventas ["ImporteVentaTotal"].plot(kind="hist",bins=10,edgecolor="white")
# Out:
# <Axes: ylabel='Frequency'>

# %%
#Grafico de bigotes
df_ventas.boxplot(column="ImporteVentaTotal")
# Out:
# <Axes: >

# %%
df_ventas.boxplot(column="ImporteVentaTotal", by="Prioridad")
# Out:
# <Axes: title={'center': 'ImporteVentaTotal'}, xlabel='Prioridad'>
